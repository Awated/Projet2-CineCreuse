# %%
import pandas as pd
url ="https://datasets.imdbws.com/title.basics.tsv.gz"
df= pd.read_csv(url, sep="\t")
# Out:
# <ipython-input-1-e3e23cc00988>:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(url, sep="\t")

# %%
import pandas as pd
df2=pd.read_csv("tmdb_full.csv", low_memory=False)
df=df2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ea0163c0694a> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df2=pd.read_csv("tmdb_full.csv", low_memory=False)
#       3 df=df2
#
# ...

# %%
df2

# %%
df2.info()

# %%
from pprint import pprint as pp

# %%
df2.isna().sum()

# %%
df2['vote_count'].mean()

# %%
df2= df2.loc[df2['vote_count'] > 60]
df2= df2.loc[df2['vote_average'] > 6]
df2["release_date"] = pd.to_datetime(df2["release_date"])
df2=df2[df2['release_date'].dt.year > 1970]
#df2=df2.drop(columns='backdrop_path')
#df2=df2.drop(columns='homepage')
#df2=df2.drop(columns='poster_path')
df2=df2[df2['runtime']< 105]
df2

# %%
from google.colab import files
df2.to_csv('df2.csv')
files.download('df2.csv')

# %%
df2['spoken_languages']
